# %% [markdown]
# ## Cloud Counselege internship
# Model 1

# %% [markdown]
# GRADUATION YEAR OF STUDENT

# %%
import numpy as np
import pandas as pd

# %%
datac = pd.read_csv("Final Lead Data.csv")
datac
# Out:
#          ID   First Name               Email Gender City  \
# 0     68112       ANIKET      aniket@xyz.com    NaN  NaN
# 1     68110    Dhanshree   dhanshree@xyz.com    NaN  NaN
# 2     68108       Dhiraj      dhiraj@xyz.com    NaN  NaN
# 3     68106        Pooja       pooja@xyz.com    NaN  NaN
# 4     68090       Aayush      aayush@xyz.com    NaN  NaN
# ...     ...          ...                 ...    ...  ...
# 5298  25834      Pratik       pratik@xyz.com    NaN  NaN
# 5299  25832       Nikita      nikita@xyz.com    NaN  NaN
# 5300  25830     Ashwini      ashwini@xyz.com    NaN  NaN
# 5301  25828  Jheanna Mae  jheannamae@xyz.com    NaN  NaN
# 5302  25826      Krishna     krishna@xyz.com    NaN  NaN
#
#                      Created Position  \
# 0     04/27/2022 01:41:38 pm      NaN
# 1     04/22/2022 04:08:38 pm      NaN
# 2     04/16/2022 10:31:59 pm      NaN
# 3     04/13/2022 10:05:15 pm      NaN
# 4     03/26/2022 07:02:48 pm      NaN
# ...                      ...      ...
# ...

# %%
datac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5303 entries, 0 to 5302
# Data columns (total 18 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      5303 non-null   int64
#  1   First Name                                              5303 non-null   object
#  2   Email                                                   5303 non-null   object
#  3   Gender                                                  200 non-null    object
#  4   City                                                    55 non-null     object
#  5   Created                                                 5303 non-null   object
#  6   Position                                                6 non-null      object
#  7   New College Name                                        1818 non-null   object
# ...

# %%
datac.drop_duplicates(subset = 'Email', inplace = True)
datac
# Out:
#          ID First Name              Email Gender City                 Created  \
# 0     68112     ANIKET     aniket@xyz.com    NaN  NaN  04/27/2022 01:41:38 pm
# 1     68110  Dhanshree  dhanshree@xyz.com    NaN  NaN  04/22/2022 04:08:38 pm
# 2     68108     Dhiraj     dhiraj@xyz.com    NaN  NaN  04/16/2022 10:31:59 pm
# 3     68106      Pooja      pooja@xyz.com    NaN  NaN  04/13/2022 10:05:15 pm
# 4     68090     Aayush     aayush@xyz.com    NaN  NaN  03/26/2022 07:02:48 pm
# ...     ...        ...                ...    ...  ...                     ...
# 5250  25940       vraj       vraj@xyz.com    NaN  NaN  10/18/2019 01:03:15 pm
# 5255  25920      Hemil      hemil@xyz.com    NaN  NaN  10/16/2019 01:37:18 pm
# 5256  25918     Shitij     shitij@xyz.com    NaN  NaN  10/16/2019 01:35:50 pm
# 5258  25914      dirgh      dirgh@xyz.com    NaN  NaN  10/16/2019 11:28:11 am
# 5260  25910   UTkarsha   utkarsha@xyz.com    NaN  NaN  10/16/2019 10:22:55 am
#
# ...

# %%
datac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2808 entries, 0 to 5260
# Data columns (total 18 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   ID                                                      2808 non-null   int64
#  1   First Name                                              2808 non-null   object
#  2   Email                                                   2808 non-null   object
#  3   Gender                                                  115 non-null    object
#  4   City                                                    54 non-null     object
#  5   Created                                                 2808 non-null   object
#  6   Position                                                1 non-null      object
#  7   New College Name                                        831 non-null    object
# ...

# %%
def convert_academic_year(year_str):
    year_mapping = {'1st year': 1, '2nd year': 2, '3rd year': 3, 'Final year': 4}
    return year_mapping.get(year_str, 0)  # Return 0 for unexpected values 

datac['What is your current academic year?'] = datac['What is your current academic year?'].apply(convert_academic_year)
datac['Academic Year'] = datac['What is your current academic year?'] + datac['Academic Year']
datac['Academic Year'].dtype
# Out:
# dtype('float64')

# %%
date_format = '%m/%d/%Y %I:%M:%S %p'
datac['Created'] = pd.to_datetime(datac['Created'], format = date_format)
datac['Year_col'] = datac['Created'].dt.year
datac
# Out:
#          ID First Name              Email Gender City             Created  \
# 0     68112     ANIKET     aniket@xyz.com    NaN  NaN 2022-04-27 13:41:38
# 1     68110  Dhanshree  dhanshree@xyz.com    NaN  NaN 2022-04-22 16:08:38
# 2     68108     Dhiraj     dhiraj@xyz.com    NaN  NaN 2022-04-16 22:31:59
# 3     68106      Pooja      pooja@xyz.com    NaN  NaN 2022-04-13 22:05:15
# 4     68090     Aayush     aayush@xyz.com    NaN  NaN 2022-03-26 19:02:48
# ...     ...        ...                ...    ...  ...                 ...
# 5250  25940       vraj       vraj@xyz.com    NaN  NaN 2019-10-18 13:03:15
# 5255  25920      Hemil      hemil@xyz.com    NaN  NaN 2019-10-16 13:37:18
# 5256  25918     Shitij     shitij@xyz.com    NaN  NaN 2019-10-16 13:35:50
# 5258  25914      dirgh      dirgh@xyz.com    NaN  NaN 2019-10-16 11:28:11
# 5260  25910   UTkarsha   utkarsha@xyz.com    NaN  NaN 2019-10-16 10:22:55
#
#      Position                      New College Name Colleges  Academic Year  \
# ...

# %%
datac['Graduation year'] = 4 - datac['Academic Year'] + datac['Year_col']
datac
# Out:
#          ID First Name              Email Gender City             Created  \
# 0     68112     ANIKET     aniket@xyz.com    NaN  NaN 2022-04-27 13:41:38
# 1     68110  Dhanshree  dhanshree@xyz.com    NaN  NaN 2022-04-22 16:08:38
# 2     68108     Dhiraj     dhiraj@xyz.com    NaN  NaN 2022-04-16 22:31:59
# 3     68106      Pooja      pooja@xyz.com    NaN  NaN 2022-04-13 22:05:15
# 4     68090     Aayush     aayush@xyz.com    NaN  NaN 2022-03-26 19:02:48
# ...     ...        ...                ...    ...  ...                 ...
# 5250  25940       vraj       vraj@xyz.com    NaN  NaN 2019-10-18 13:03:15
# 5255  25920      Hemil      hemil@xyz.com    NaN  NaN 2019-10-16 13:37:18
# 5256  25918     Shitij     shitij@xyz.com    NaN  NaN 2019-10-16 13:35:50
# 5258  25914      dirgh      dirgh@xyz.com    NaN  NaN 2019-10-16 11:28:11
# 5260  25910   UTkarsha   utkarsha@xyz.com    NaN  NaN 2019-10-16 10:22:55
#
#      Position                      New College Name Colleges  Academic Year  \
# ...

# %%
datac.describe()
# Out:
#                  ID                        Created  Academic Year  \
# count   2808.000000                           2808    1083.000000
# mean   45108.948006  2020-09-03 11:05:26.481125376       2.810711
# min    25910.000000            2019-10-16 10:22:55       1.000000
# 25%    33378.000000            2020-02-27 23:37:20       2.000000
# 50%    39501.000000     2020-07-14 11:29:49.500000       3.000000
# 75%    64193.000000  2021-02-19 13:11:33.249999872       3.000000
# max    68112.000000            2022-04-27 13:41:38       4.000000
# std    14440.621811                            NaN       0.814719
#
#        What is your current academic year?     Year_col  Graduation year
# count                               2808.0  2808.000000      1083.000000
# mean                                   0.0  2020.320513      2021.506002
# min                                    0.0  2019.000000      2019.000000
# 25%                                    0.0  2020.000000      2021.000000
# ...

# %% [markdown]
# This shows that the maximum no. of students graduate in the year of 2024 then 2022, 2021 and the minimum of them in the year of 2019.

# %% [markdown]
# ## Exporting the file to Excel

# %%
file_path = "Academic Tracker of Student.xlsx"
datac.to_excel(file_path, index = False)
print(f"{file_path} this DataFrame has been exported")
# Out:
# Academic Tracker of Student.xlsx this DataFrame has been exported
